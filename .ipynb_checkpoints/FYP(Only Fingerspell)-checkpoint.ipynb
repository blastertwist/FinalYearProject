# %% [markdown]
# ## Import Libaries

# %%
# Numeric Libaries
import numpy as np

# Mediapipe Libaries
import mediapipe as mp

# Tensorflow Libraries
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import load_model

# Scikit Learn Libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# Camera Libaries
import cv2

# Other Libraries
import os

# %% [markdown]
# ## Declare Mediapipe Variables

# %%
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_holistic = mp.solutions.holistic

# %%
# Draw and Set Landmark
def draw_landmarks(img, res):
    # Render Left Hand Connections
    mp_drawing.draw_landmarks(img, res.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                            mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                            mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                            ) 
    # Render Right Hand Connections
    mp_drawing.draw_landmarks(img, res.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                            mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                            mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                            )           

def mediapipe_detection(img, model):
    # Set Flags Writeable False, to optimze the detection process
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img.flags.writeable = False
        
    # Holistic model return landmarks
    results = model.process(img)

    # Draw Detection on the footage/image
    img.flags.writeable = True
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        
    return img, results

# %% [markdown]
# ## Dataset Collection

# %%
def generate_keypoints(results):
    left_hand = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    right_hand = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
        
    return np.concatenate([left_hand, right_hand])

# %%
# Check Label Folder (Create if not exists)
def create_folder_label(dataset_dir, label, sequence_length):
        
    for sequence_num in range(sequence_length):
        try:
            os.makedirs(os.path.join(dataset_dir, label, str(sequence_num)))
        except:
            pass

# %%
def collect_dataset(dataset_dir, label_name, sequence_length, frame_length):
    create_folder_label(dataset_dir, label_name, sequence_length)
    cap = cv2.VideoCapture(0)
    # Set mediapipe model 
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        # Loop through sequences aka videos
        for sequence in range(0, sequence_length):
            # Loop through video length aka sequence length
            for frame_num in range(frame_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_landmarks(image, results)

                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(label_name, sequence), (15,12), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(100)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(label_name, sequence), (15,12), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)

                # NEW Export keypoints
                keypoints = generate_keypoints(results)
                npy_path = os.path.join(dataset_dir, label_name, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break

    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ## Declare Some Variables

# %%
dataset_dir = os.path.join("dataset_collections")
sequence_length = 30
frame_length = 30

# %% [markdown]
# ## Main

# %%
def main():
    label_name = input("Enter Label Name:")
    collect_dataset(dataset_dir, label_name, sequence_length, frame_length)

# %%
if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [61], in <module>
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Input In [8], in main()
#       1 def main():
# ----> 2     label_name = input("Enter Label Name:")
#       3     collect_dataset(dataset_dir, label_name, sequence_length, frame_length)
#
# File c:\users\hunter-pc\appdata\local\programs\python\python38\lib\site-packages\ipykernel\kernelbase.py:1044, in Kernel.raw_input(self, prompt)
#    1040 if not self._allow_stdin:
#    1041     raise StdinNotImplementedError(
#    1042         "raw_input was called, but this frontend does not support input requests."
#    1043     )
# -> 1044 return self._input_request(
#    1045     str(prompt),
#    1046     self._parent_ident["shell"],
#    1047     self.get_parent("shell"),
#    1048     password=False,
#    1049 )
#
# File c:\users\hunter-pc\appdata\local\programs\python\python38\lib\site-packages\ipykernel\kernelbase.py:1089, in Kernel._input_request(self, prompt, ident, parent, password)
#    1086             break
#    1087 except KeyboardInterrupt:
#    1088     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1089     raise KeyboardInterrupt("Interrupted by user") from None
#    1090 except Exception:
#    1091     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## Processing Data

# %%
def fast_scandir(dirname):
    labels = []
    for root, dirs, _ in os.walk(dirname):
        labels = dirs
        break
    return labels

# %%
actions = fast_scandir(dataset_dir)

# %%
actions = np.array(actions)

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(dataset_dir, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(dataset_dir, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (120, 30, 126)

# %%
np.array(labels).shape
# Out:
# (120,)

# %%
X = np.array(sequences)

# %%
Y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.05, shuffle=True)

# %% [markdown]
# ## Create Model

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,126)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000)
# Out:
# Epoch 1/2000
# 4/4 [==============================] - 3s 41ms/step - loss: 1.3878 - categorical_accuracy: 0.2281
# Epoch 2/2000
# 4/4 [==============================] - 0s 49ms/step - loss: 1.3796 - categorical_accuracy: 0.3421
# Epoch 3/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 1.3682 - categorical_accuracy: 0.3421
# Epoch 4/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 1.3475 - categorical_accuracy: 0.3772
# Epoch 5/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 1.2939 - categorical_accuracy: 0.3860
# Epoch 6/2000
# 4/4 [==============================] - 0s 45ms/step - loss: 1.2366 - categorical_accuracy: 0.3947
# Epoch 7/2000
# 4/4 [==============================] - 0s 45ms/step - loss: 1.1448 - categorical_accuracy: 0.4561
# Epoch 8/2000
# 4/4 [==============================] - 0s 42ms/step - loss: 1.0625 - categorical_accuracy: 0.5526
# Epoch 9/2000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.9876 - categorical_accuracy: 0.6754
# Epoch 10/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.8580 - categorical_accuracy: 0.4474
# Epoch 11/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.3586 - categorical_accuracy: 0.2544
# Epoch 12/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.3325 - categorical_accuracy: 0.2632
# Epoch 13/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.3056 - categorical_accuracy: 0.4298
# Epoch 14/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.2371 - categorical_accuracy: 0.5175
# Epoch 15/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.1915 - categorical_accuracy: 0.4912
# Epoch 16/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.2004 - categorical_accuracy: 0.4298
# Epoch 17/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 1.2535 - categorical_accuracy: 0.3772
# Epoch 18/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 1.1013 - categorical_accuracy: 0.5439
# Epoch 19/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 1.0780 - categorical_accuracy: 0.5439
# Epoch 20/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 1.0130 - categorical_accuracy: 0.5351
# Epoch 21/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.1150 - categorical_accuracy: 0.5175
# Epoch 22/2000
# 4/4 [==============================] - 0s 43ms/step - loss: 1.1098 - categorical_accuracy: 0.5175
# Epoch 23/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.9879 - categorical_accuracy: 0.5965
# Epoch 24/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.8093 - categorical_accuracy: 0.5877
# Epoch 25/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.8194 - categorical_accuracy: 0.5877
# Epoch 26/2000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.9067 - categorical_accuracy: 0.5789
# Epoch 27/2000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.8659 - categorical_accuracy: 0.5877
# Epoch 28/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.8896 - categorical_accuracy: 0.6404
# Epoch 29/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.7721 - categorical_accuracy: 0.6404
# Epoch 30/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.6533 - categorical_accuracy: 0.7193
# Epoch 31/2000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.5944 - categorical_accuracy: 0.8158
# Epoch 32/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.7860 - categorical_accuracy: 0.6754
# Epoch 33/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.9678 - categorical_accuracy: 0.4912
# Epoch 34/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.7675 - categorical_accuracy: 0.7193
# Epoch 35/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.8730 - categorical_accuracy: 0.6491
# Epoch 36/2000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.8337 - categorical_accuracy: 0.7544
# Epoch 37/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.7925 - categorical_accuracy: 0.7719
# Epoch 38/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.7149 - categorical_accuracy: 0.7456
# Epoch 39/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.6042 - categorical_accuracy: 0.8246
# Epoch 40/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5548 - categorical_accuracy: 0.8070
# Epoch 41/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.4919 - categorical_accuracy: 0.8333
# Epoch 42/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.4324 - categorical_accuracy: 0.8684
# Epoch 43/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3634 - categorical_accuracy: 0.8509
# Epoch 44/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3255 - categorical_accuracy: 0.8860
# Epoch 45/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3166 - categorical_accuracy: 0.8509
# Epoch 46/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.6693 - categorical_accuracy: 0.7632
# Epoch 47/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4103 - categorical_accuracy: 0.7807
# Epoch 48/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3310 - categorical_accuracy: 0.8772
# Epoch 49/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3509 - categorical_accuracy: 0.8509
# Epoch 50/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2614 - categorical_accuracy: 0.8772
# Epoch 51/2000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.2167 - categorical_accuracy: 0.8860
# Epoch 52/2000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1899 - categorical_accuracy: 0.8860
# Epoch 53/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.1656 - categorical_accuracy: 0.9035
# Epoch 54/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1672 - categorical_accuracy: 0.9123
# Epoch 55/2000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1450 - categorical_accuracy: 0.9123
# Epoch 56/2000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.1872 - categorical_accuracy: 0.9211
# Epoch 57/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.5858 - categorical_accuracy: 0.7895
# Epoch 58/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.4176 - categorical_accuracy: 0.5965
# Epoch 59/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.7094 - categorical_accuracy: 0.6491
# Epoch 60/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.9905 - categorical_accuracy: 0.5175
# Epoch 61/2000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.6958 - categorical_accuracy: 0.6316
# Epoch 62/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.6882 - categorical_accuracy: 0.8070
# Epoch 63/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.6262 - categorical_accuracy: 0.7632
# Epoch 64/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.4877 - categorical_accuracy: 0.8684
# Epoch 65/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5113 - categorical_accuracy: 0.8070
# Epoch 66/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4171 - categorical_accuracy: 0.8421
# Epoch 67/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4164 - categorical_accuracy: 0.8772
# Epoch 68/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0

# 4/4 [==============================] - 0s 39ms/step - loss: 0.9590 - categorical_accuracy: 0.5614
# Epoch 188/2000
# 4/4 [==============================] - 0s 41ms/step - loss: 1.0033 - categorical_accuracy: 0.4912
# Epoch 189/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.0631 - categorical_accuracy: 0.5000
# Epoch 190/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.0297 - categorical_accuracy: 0.4912
# Epoch 191/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.9890 - categorical_accuracy: 0.5175
# Epoch 192/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.9723 - categorical_accuracy: 0.5351
# Epoch 193/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.9330 - categorical_accuracy: 0.6140
# Epoch 194/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.8806 - categorical_accuracy: 0.6667
# Epoch 195/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.8254 - categorical_accuracy: 0.7632
# Epoch 196/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.7732 - categorical_accuracy: 0.7632
# Epoch 197/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.7095 - categorical_accuracy: 0.7895
# Epoch 198/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.6607 - categorical_accuracy: 0.7281
# Epoch 199/2000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.6100 - categorical_accuracy: 0.7193
# Epoch 200/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5564 - categorical_accuracy: 0.7807
# Epoch 201/2000
# 4/4 [==============================] - ETA: 0s - loss: 0.5370 - categorical_accuracy: 0.84 - 0s 38ms/step - loss: 0.5255 - categorical_accuracy: 0.8509
# Epoch 202/2000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.4864 - categorical_accuracy: 0.8947
# Epoch 203/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.4649 - categorical_accuracy: 0.8684
# Epoch 204/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.4392 - categorical_accuracy: 0.8860
# Epoch 205/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.4106 - categorical_accuracy: 0.9123
# Epoch 206/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.4353 - categorical_accuracy: 0.8860
# Epoch 207/2000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.4728 - categorical_accuracy: 0.8421
# Epoch 208/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.3978 - categorical_accuracy: 0.8860
# Epoch 209/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.3995 - categorical_accuracy: 0.8860
# Epoch 210/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.3462 - categorical_accuracy: 0.9035
# Epoch 211/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3124 - categorical_accuracy: 0.9386
# Epoch 212/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3008 - categorical_accuracy: 0.9123
# Epoch 213/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2808 - categorical_accuracy: 0.9386
# Epoch 214/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2491 - categorical_accuracy: 0.9474
# Epoch 215/2000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.2488 - categorical_accuracy: 0.9298
# Epoch 216/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2323 - categorical_accuracy: 0.9298
# Epoch 217/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.2651 - categorical_accuracy: 0.9123
# Epoch 218/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.4182 - categorical_accuracy: 0.8421
# Epoch 219/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3791 - categorical_accuracy: 0.8246
# Epoch 220/2000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2254 - categorical_accuracy: 0.9035
# Epoch 221/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1873 - categorical_accuracy: 0.9211
# Epoch 222/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2128 - categorical_accuracy: 0.9211
# Epoch 223/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1845 - categorical_accuracy: 0.9298
# Epoch 224/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1305 - categorical_accuracy: 0.9737
# Epoch 225/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1487 - categorical_accuracy: 0.9474
# Epoch 226/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1261 - categorical_accuracy: 0.9474
# Epoch 227/2000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1088 - categorical_accuracy: 0.9649
# Epoch 228/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.1071 - categorical_accuracy: 0.9561
# Epoch 229/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0866 - categorical_accuracy: 0.9649
# Epoch 230/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0699 - categorical_accuracy: 0.9737
# Epoch 231/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0874 - categorical_accuracy: 0.9561
# Epoch 232/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0696 - categorical_accuracy: 0.9737
# Epoch 233/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0647 - categorical_accuracy: 0.9737
# Epoch 234/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0680 - categorical_accuracy: 0.9825
# Epoch 235/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1142 - categorical_accuracy: 0.9737
# Epoch 236/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1797 - categorical_accuracy: 0.9298
# Epoch 237/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1922 - categorical_accuracy: 0.9123
# Epoch 238/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0881 - categorical_accuracy: 0.9737
# Epoch 239/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1270 - categorical_accuracy: 0.9561
# Epoch 240/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0633 - categorical_accuracy: 0.9825
# Epoch 241/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1407 - categorical_accuracy: 0.9386
# Epoch 242/2000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0859 - categorical_accuracy: 0.9561
# Epoch 243/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0639 - categorical_accuracy: 0.9737
# Epoch 244/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0476 - categorical_accuracy: 0.9825
# Epoch 245/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0542 - categorical_accuracy: 0.9737
# Epoch 246/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0423 - categorical_accuracy: 0.9912
# Epoch 247/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0339 - categorical_accuracy: 0.9825
# Epoch 248/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0275 - categorical_accuracy: 0.9912
# Epoch 249/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0424 - categorical_accuracy: 0.9825
# Epoch 250/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0343 - categorical_accuracy: 0.9825
# Epoch 251/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1459 - categorical_accuracy: 0.9561
# Epoch 252/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1169 - categorical_accuracy: 0.9561
# Epoch 253/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1004 - categorical_accuracy: 0.9474
# Epoch 254/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1456 - categorical_accuracy: 0.9386
# Epoch 255/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0755 - categorical_accuracy: 0.9737
# Epoch 256/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0516 - categorical_accuracy: 0.9912
# Epoch 257/2000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0433 - categorical_accuracy: 0.9825
# Epoch 258/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0355 - categorical_accuracy: 0.9912
# Epoch 259/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0699 - categorical_accuracy: 0.9737
# Epoch 260/2000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0614 - categorical_accuracy: 0.9737
# Epoch 261/2000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0690 - categorical_accuracy: 0.9737
# Epoch 262/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0516 - categorical_accuracy: 0.9825
# Epoch 263/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0350 - categorical_accuracy: 0.9912
# Epoch 264/2000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0266 - categorical_accuracy: 0.9912
# Epoch 265/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0336 - categorical_accuracy: 0.9912
# Epoch 266/2000
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0136 - categorical_accuracy: 1.0000
# Epoch 267/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0258 - categorical_accuracy: 1.0000
# Epoch 268/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0260 - categorical_accuracy: 0.9912
# Epoch 269/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0248 - categorical_accuracy: 0.9912
# Epoch 270/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0254 - categorical_accuracy: 0.9912
# Epoch 271/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0151 - categorical_accuracy: 0.9912
# Epoch 272/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0643 - categorical_accuracy: 0.9737
# Epoch 273/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.7104 - categorical_accuracy: 0.9035
# Epoch 274/2000
# 4/4 [==============================] - 0s 42ms/step - loss: 4.0724 - categorical_accuracy: 0.4035
# Epoch 275/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 1.2100 - categorical_accuracy: 0.5439
# Epoch 276/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.4528 - categorical_accuracy: 0.4912
# Epoch 277/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 1.2764 - categorical_accuracy: 0.5000
# Epoch 278/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.0294 - categorical_accuracy: 0.5175
# Epoch 279/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.9569 - categorical_accuracy: 0.5175
# Epoch 280/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.9303 - categorical_accuracy: 0.5702
# Epoch 281/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.8374 - categorical_accuracy: 0.6754
# Epoch 282/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.7464 - categorical_accuracy: 0.7018
# Epoch 283/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.7038 - categorical_accuracy: 0.6404
# Epoch 284/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.6332 - categorical_accuracy: 0.7807
# Epoch 285/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.5751 - categorical_accuracy: 0.8246
# Epoch 286/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.5087 - categorical_accuracy: 0.8421
# Epoch 287/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4579 - categorical_accuracy: 0.9123
# Epoch 288/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3926 - categorical_accuracy: 0.9386
# Epoch 289/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.3384 - categorical_accuracy: 0.9474
# Epoch 290/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2646 - categorical_accuracy: 0.9474
# Epoch 291/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.1952 - categorical_accuracy: 0.9649
# Epoch 292/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.6706 - categorical_accuracy: 0.8333
# Epoch 293/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5215 - categorical_accuracy: 0.7368
# Epoch 294/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.6191 - categorical_accuracy: 0.7982
# Epoch 295/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.4693 - categorical_accuracy: 0.8070
# Epoch 296/2000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.4412 - categorical_accuracy: 0.8158
# Epoch 297/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.4049 - categorical_accuracy: 0.8860
# Epoch 298/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.3990 - categorical_accuracy: 0.8772
# Epoch 299/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.3643 - categorical_accuracy: 0.9123
# Epoch 300/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.3479 - categorical_accuracy: 0.9211
# Epoch 301/2000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.3389 - categorical_accuracy: 0.9298
# Epoch 302/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.3252 - categorical_accuracy: 0.9123
# Epoch 303/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.3112 - categorical_accuracy: 0.9386
# Epoch 304/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.3013 - categorical_accuracy: 0.9649
# Epoch 305/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2935 - categorical_accuracy: 0.9386
# Epoch 306/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2882 - categorical_accuracy: 0.9561
# Epoch 307/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2553 - categorical_accuracy: 0.9737
# Epoch 308/2000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.2455 - categorical_accuracy: 0.9474
# Epoch 309/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2457 - categorical_accuracy: 0.9649
# Epoch 310/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.2395 - categorical_accuracy: 0.9561
# Epoch 311/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2228 - categorical_accuracy: 0.9737
# Epoch 312/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2100 - categorical_accuracy: 0.9737
# Epoch 313/2000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1817 - categorical_accuracy: 0.9649
# Epoch 314/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.1558 - categorical_accuracy: 0.9912
# Epoch 315/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.1266 - categorical_accuracy: 0.9737
# Epoch 316/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.3648 - categorical_accuracy: 0.8860
# Epoch 317/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4480 - categorical_accuracy: 0.8246
# Epoch 318/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1869 - categorical_accuracy: 0.9474
# Epoch 319/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1762 - categorical_accuracy: 0.9649
# Epoch 320/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2160 - categorical_accuracy: 0.9474
# Epoch 321/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1771 - categorical_accuracy: 0.9561
# Epoch 322/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1679 - categorical_accuracy: 0.9912
# Epoch 323/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1428 - categorical_accuracy: 0.9912
# Epoch 324/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1299 - categorical_accuracy: 1.0000
# Epoch 325/2000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1214 - categorical_accuracy: 0.9912
# Epoch 326/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.1019 - categorical_accuracy: 1.0000
# Epoch 327/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0865 - categorical_accuracy: 0.9912
# Epoch 328/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0728 - categorical_accuracy: 0.9912
# Epoch 329/2000
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0553 - categorical_accuracy: 1.0000
# Epoch 330/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0434 - categorical_accuracy: 1.0000
# Epoch 331/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0322 - categorical_accuracy: 1.0000
# Epoch 332/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0244 - categorical_accuracy: 1.0000
# Epoch 333/2000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0196 - categorical_accuracy: 1.0000
# Epoch 334/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0181 - categorical_accuracy: 0.9912
# Epoch 335/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0273 - categorical_accuracy: 1.0000
# Epoch 336/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0100 - categorical_accuracy: 1.0000
# Epoch 337/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0079 - categorical_accuracy: 1.0000
# Epoch 338/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0061 - categorical_accuracy: 1.0000
# Epoch 339/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0048 - categorical_accuracy: 1.0000
# Epoch 340/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0031 - categorical_accuracy: 1.0000
# Epoch 341/2000
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 342/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 343/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0015 - categorical_accuracy: 1.0000
# Epoch 344/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0013 - categorical_accuracy: 1.0000
# Epoch 345/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0010 - categorical_accuracy: 1.0000
# Epoch 346/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 8.4413e-04 - categorical_accuracy: 1.0000
# Epoch 347/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 7.1678e-04 - categorical_accuracy: 1.0000
# Epoch 348/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 5.7819e-04 - categorical_accuracy: 1.0000
# Epoch 349/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 4.8266e-04 - categorical_accuracy: 1.0000
# Epoch 350/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 4.0914e-04 - categorical_accuracy: 1.0000
# Epoch 351/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 3.5103e-04 - categorical_accuracy: 1.0000
# Epoch 352/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 3.0119e-04 - categorical_accuracy: 1.0000
# Epoch 353/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 2.5220e-04 - categorical_accuracy: 1.0000
# Epoch 354/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 2.0689e-04 - categorical_accuracy: 1.0000
# Epoch 355/2000
# 4/4 [==============================] - 0s 43ms/step - loss: 1.7276e-04 - categorical_accuracy: 1.0000
# Epoch 356/2000
# 4/4 [==============================] - 0s 42ms/step - loss: 1.7152e-04 - categorical_accuracy: 1.0000
# Epoch 357/2000
# 4/4 [==============================] - 0s 40ms/step - loss: 1.3100e-04 - categorical_accuracy: 1.0000
# Epoch 358/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 1.3437e-04 - categorical_accuracy: 1.0000
# Epoch 359/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.2234e-04 - categorical_accuracy: 1.0000
# Epoch 360/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.0903e-04 - categorical_accuracy: 1.0000
# Epoch 361/2000
# 4/4 [==============================] - 0s 45ms/step - loss: 7.5484e-05 - categorical_accuracy: 1.0000
# Epoch 362/2000
# 4/4 [==============================] - 0s 41ms/step - loss: 7.2879e-05 - categorical_accuracy: 1.0000
# Epoch 363/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 7.2381e-05 - categorical_accuracy: 1.0000
# Epoch 364/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 5.6867e-05 - categorical_accuracy: 1.0000
# Epoch 365/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 4.9051e-05 - categorical_accuracy: 1.0000
# Epoch 366/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 4.8923e-05 - categorical_accuracy: 1.0000
# Epoch 367/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 4.6465e-05 - categorical_accuracy: 1.0000
# Epoch 368/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 3.8576e-05 - categorical_accuracy: 1.0000
# Epoch 369/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 3.5401e-05 - categorical_accuracy: 1.0000
# Epoch 370/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 3.3521e-05 - categorical_accuracy: 1.0000
# Epoch 371/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 3.0461e-05 - categorical_accuracy: 1.0000
# Epoch 372/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 2.8126e-05 - categorical_accuracy: 1.0000
# Epoch 373/2000
# 4/4 [==============================] - 0s 41ms/step - loss: 2.6708e-05 - categorical_accuracy: 1.0000
# Epoch 374/2000
# 4/4 [==============================] - 0s 41ms/step - loss: 2.4816e-05 - categorical_accuracy: 1.0000
# Epoch 375/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 2.2592e-05 - categorical_accuracy: 1.0000
# Epoch 376/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 2.2100e-05 - categorical_accuracy: 1.0000
# Epoch 377/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 2.0878e-05 - categorical_accuracy: 1.0000
# Epoch 378/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.9272e-05 - categorical_accuracy: 1.0000
# Epoch 379/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.7912e-05 - categorical_accuracy: 1.0000
# Epoch 380/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.8547e-05 - categorical_accuracy: 1.0000
# Epoch 381/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.7709e-05 - categorical_accuracy: 1.0000
# Epoch 382/2000
# 4/4 [==============================] - 0s 34ms/step - loss: 1.5976e-05 - categorical_accuracy: 1.0000
# Epoch 383/2000
# 4/4 [==============================] - 0s 36ms/step - loss: 1.5367e-05 - categorical_accuracy: 1.0000
# Epoch 384/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 1.5192e-05 - categorical_accuracy: 1.0000
# Epoch 385/2000
# 4/4 [==============================] - 0s 33ms/step - loss: 1.4681e-05 - categorical_accuracy: 1.0000
# Epoch 386/2000
# 4/4 [==============================] - 0s 35ms/step - loss: 1.4280e-05 - categorical_accuracy: 1.0000
# Epoch 387/2000
# 4/4 [==============================] - 0s 44ms/step - loss: 1.3310e-05 - categorical_accuracy: 1.0000
# Epoch 388/2000
# 4/4 [==============================] - 0s 46ms/step - loss: 1.2685e-05 - categorical_accuracy: 1.0000
# Epoch 389/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 1.2008e-05 - categorical_accuracy: 1.0000
# Epoch 390/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 1.1624e-05 - categorical_accuracy: 1.0000
# Epoch 391/2000
# 4/4 [==============================] - 0s 45ms/step - loss: 1.1318e-05 - categorical_accuracy: 1.0000
# Epoch 392/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 1.1032e-05 - categorical_accuracy: 1.0000
# Epoch 393/2000
# 4/4 [==============================] - 0s 39ms/step - loss: 1.0269e-05 - categorical_accuracy: 1.0000
# Epoch 394/2000
# 4/4 [==============================] - 0s 37ms/step - loss: 9.9596e-06 - categorical_accuracy: 1.0000
# Epoch 395/2000
# 4/4 [==============================] - 0s 38ms/step - loss: 9.5434e-06 - categorical_accuracy: 1.0000
# Epoch 396/2000
# 4/4 [==============================] - 0s 42ms/step - loss: 9.6019e-06 - categorical_accuracy: 1.0000
# Epoch 397/2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [55], in <module>
# ----> 1 model.fit(X_train, y_train, epochs=2000)
#
# File c:\users\hunter-pc\appdata\local\programs\python\python38\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\users\hunter-pc\appdata\local\programs\python\python38\lib\site-packages\keras\engine\training.py:1216, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1209 with tf.profiler.experimental.Trace(
#    1210     'train',
#    1211     epoch_num=epoch,
#    1212     step_num=step,
#    1213     batch_size=batch_size,
#    1214     _r=1):
#    1215   callbacks.on_train_batch_begin(step)
# -> 1216   tmp_logs = self.train_function(iterator)
#    1217   if data_handler.should_sync:
#    1218     context.async_wait()
#
# File c:\users\hunter-pc\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\users\hunter-pc\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\def_function.py:910, in Function.__call__(self, *args, **kwds)
#     907 compiler = "xla" if self._jit_compile else "nonXla"
#     909 with OptionalXlaContext(self._jit_compile):
# --> 910   result = self._call(*args, **kwds)
#     912 new_tracing_count = self.experimental_get_tracing_count()
#     913 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\users\hunter-pc\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\def_function.py:942, in Function._call(self, *args, **kwds)
#     939   self._lock.release()
#     940   # In this case we have created variables on the first call, so we run the
#     941   # defunned version which is guaranteed to never create variables.
# --> 942   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943 elif self._stateful_fn is not None:
#     944   # Release the lock early so that multiple threads can perform the call
#     945   # in parallel.
#     946   self._lock.release()
#
# File c:\users\hunter-pc\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py:3130, in Function.__call__(self, *args, **kwargs)
#    3127 with self._lock:
#    3128   (graph_function,
#    3129    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130 return graph_function._call_flat(
#    3131     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\users\hunter-pc\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py:1959, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1955 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1956 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1957     and executing_eagerly):
#    1958   # No tape is watching; skip to running the function.
# -> 1959   return self._build_call_outputs(self._inference_function.call(
#    1960       ctx, args, cancellation_manager=cancellation_manager))
#    1961 forward_backward = self._select_forward_and_backward_functions(
#    1962     args,
#    1963     possible_gradient_type,
#    1964     executing_eagerly)
#    1965 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\users\hunter-pc\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py:598, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     596 with _InterpolateFunctionError(self):
#     597   if cancellation_manager is None:
# --> 598     outputs = execute.execute(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#     601         inputs=args,
#     602         attrs=attrs,
#     603         ctx=ctx)
#     604   else:
#     605     outputs = execute.execute_with_cancellation(
#     606         str(self.signature.name),
#     607         num_outputs=self._num_outputs,
#    (...)
#     610         ctx=ctx,
#     611         cancellation_manager=cancellation_manager)
#
# File c:\users\hunter-pc\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\execute.py:58, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56 try:
#      57   ctx.ensure_initialized()
# ---> 58   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                       inputs, attrs, num_outputs)
#      60 except core._NotOkStatusException as e:
#      61   if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 30, 64)            48896
#
#  lstm_7 (LSTM)               (None, 30, 128)           98816
#
#  lstm_8 (LSTM)               (None, 64)                49408
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dense_8 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 203,492
# Trainable params: 203,492
# Non-trainable params: 0
# _________________________________________________________________

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# ## Realtime Test

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.98

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.4) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = generate_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-20:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# O
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# V
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# L
